# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# Renomeando colunas para refletir cada matéria
df_mat.columns = ['Matemática']
df_por.columns = ['Português']
df_geo.columns = ['Geografia']
df_ing.columns = ['Inglês']
df_his.columns = ['História']
df_fis.columns = ['Física']
df_qui.columns = ['Química']

# Concatenação dos DataFrames para formar um único DataFrame com todas as matérias
df_resultados = pd.concat([df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui], axis=1)

# Calculando o percentual de acertos por assunto
df_percentuais = df_resultados.copy()
df_percentuais['Matemática'] /= 24
df_percentuais['Português'] /= 18
df_percentuais['Geografia'] /= 8
df_percentuais['Inglês'] /= 8
df_percentuais['História'] /= 8
df_percentuais['Física'] /= 12
df_percentuais['Química'] /= 12

print("Percentuais de acerto por assunto:\n", df_percentuais.head())
# Out:
# Percentuais de acerto por assunto:
#     Matemática  Português  Geografia  Inglês  História    Física   Química
# 0    0.250000   0.388889      0.875   0.375     0.125  0.666667  0.250000
# 1    0.791667   0.555556      0.000   0.000     0.000  0.916667  0.666667
# 2    0.583333   0.888889      0.000   0.625     0.875  0.333333  0.333333
# 3    0.416667   0.388889      0.375   0.500     0.000  0.000000  0.666667
# 4    0.291667   0.111111      0.250   0.875     0.000  0.750000  0.250000

# %%
# Calculando o total de acertos de cada aluno
df_resultados['Total_acertos'] = df_resultados.sum(axis=1)

print("\nTotal de acertos por aluno:\n", df_resultados['Total_acertos'].head())
# Out:
# Total de acertos por aluno:
#  0    35
# 1    48
# 2    50
# 3    32
# 4    30
# Name: Total_acertos, dtype: int64

# %%
# Calculando o percentual geral de acerto de cada aluno (total de questões é 90)
df_resultados['Percentual_geral'] = df_resultados['Total_acertos'] / 90

print("\nPercentual geral de acerto por aluno:\n", df_resultados['Percentual_geral'].head())
# Out:
# Percentual geral de acerto por aluno:
#  0    0.388889
# 1    0.533333
# 2    0.555556
# 3    0.355556
# 4    0.333333
# Name: Percentual_geral, dtype: float64

# %%
# Contando quantos alunos tiveram nota maior que 45
alunos_acima_corte = (df_resultados['Total_acertos'] > 45).sum()

print("\nNúmero de alunos com nota acima de 45:", alunos_acima_corte)
# Out:
# Número de alunos com nota acima de 45: 31

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# Identificação dos alunos desqualificados
df_desqualificados = df_resultados[(df_resultados['Matemática'] == 0) | (df_resultados['Física'] == 0) | (df_resultados['Química'] == 0)]

# Contagem dos alunos desqualificados
num_desqualificados = df_desqualificados.shape[0]

# Cálculo da média de História e Geografia para os alunos desqualificados
media_his_geo_desq = df_desqualificados[['História', 'Geografia']].mean()

# Criando o DataFrame para os alunos que passaram para a segunda fase
df_passaram = df_resultados[(df_resultados['Matemática'] > 0) & (df_resultados['Física'] > 0) & (df_resultados['Química'] > 0)]
df_passaram = df_passaram[df_passaram.sum(axis=1) > 45]  # Nota de corte é 45

# Resultados
print("Número de alunos desqualificados:", num_desqualificados)
print("Média de História e Geografia dos desqualificados:\n", media_his_geo_desq)
print("Número de alunos que passaram para a segunda fase:", df_passaram.shape[0])
# Out:
# Número de alunos desqualificados: 23
# Média de História e Geografia dos desqualificados:
#  História     3.434783
# Geografia    3.217391
# dtype: float64
# Número de alunos que passaram para a segunda fase: 76

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')
# Out:
# /tmp/ipykernel_222211/3461214207.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')

# %%
num_vaccination_records = df.shape[0]
print(num_vaccination_records)
# Out:
# 384612

# %%
num_unique_patients = df['paciente_id'].nunique()
print(num_unique_patients)
# Out:
# 314795

# %%
first_dose_unique_patients = df[df['vacina_descricao_dose'].str.contains('1ª Dose')]['paciente_id'].nunique()
print(first_dose_unique_patients)
# Out:
# 142984

# %%
patients_under_18 = df[df['paciente_idade'] < 18]['paciente_id'].nunique()
print(patients_under_18)
# Out:
# 67031

# %%
num_unique_establishments = df['estabelecimento_valor'].nunique()
print(num_unique_establishments)
# Out:
# 210

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
df_under_18 = df[df['paciente_idade'] < 18].copy()

# %%
columns_list = df_under_18.columns.tolist()
columns_list
# Out:
# ['document_id',
#  'paciente_id',
#  'paciente_idade',
#  'paciente_dataNascimento',
#  'paciente_enumSexoBiologico',
#  'paciente_racaCor_codigo',
#  'paciente_racaCor_valor',
#  'paciente_endereco_coIbgeMunicipio',
#  'paciente_endereco_coPais',
#  'paciente_endereco_nmMunicipio',
#  'paciente_endereco_nmPais',
#  'paciente_endereco_uf',
#  'paciente_endereco_cep',
#  'paciente_nacionalidade_enumNacionalidade',
#  'estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'vacina_grupoAtendimento_codigo',
#  'vacina_grupoAtendimento_nome',
#  'vacina_categoria_codigo',
#  'vacina_categoria_nome',
#  'vacina_lote',
#  'vacina_fabricante_nome',
#  'vacina_fabricante_referencia',
#  'vacina_dataAplicacao',
#  'vacina_descricao_dose',
#  'vacina_codigo',
#  'vacina_nome',
#  'sistema_origem']

# %%
vaccine_category_counts = df_under_18['vacina_categoria_nome'].value_counts()
vaccine_category_counts
# Out:
# Faixa Etária                                      46342
# Povos Indígenas                                    4457
# Outros                                             3755
# Povos e Comunidades Tradicionais                    807
# Trabalhadores de Saúde                              245
# Comorbidades                                         56
# População Privada de Liberdade                       53
# Gestantes                                            41
# Pessoas com Deficiência                              11
# Pessoas Institucionalizadas                           3
# Pessoas de 60 anos ou mais institucionalizadas        1
# Puérperas                                             1
# Trabalhadores da Educação                             1
# Name: vacina_categoria_nome, dtype: int64

# %%
establishment_columns = [
    'estabelecimento_valor',
    'estabelecimento_razaoSocial',
    'estalecimento_noFantasia',
    'estabelecimento_municipio_codigo',
    'estabelecimento_municipio_nome',
    'estabelecimento_uf'
]

# %%
df_establishments = df_under_18[establishment_columns + ['vacina_categoria_nome']]
df_establishments
# Out:
#         estabelecimento_valor              estabelecimento_razaoSocial  \
# 2                     6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 8                     6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 11                    2001349        PREFEITURA MUNICIPAL DE BRASILEIA
# 12                    6159087  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 20                    3810771         PREFEITURA MUNICIPAL DE TARAUACA
# ...                       ...                                      ...
# 384594                2000105      PREFEITURA MUNICIPAL DE MANCIO LIMA
# 384595                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 384600                6612385         PREFEITURA MUNICIPAL DE TARAUACA
# 384602                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 384603                2001128       PREFEITURA MUNICIPAL DE PORTO ACRE
#
#                                  estalecimento_noFantasia  \
# 2       DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 8       DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 11                                 ESF TUFIC MIZAEL SAADY
# 12       SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL
# 20      UNIDADE DE S DA FAMILIA DR JOSE LEONCIO GOMES ...
# ...                                                   ...
# 384594                    U S F QUINTINO RIO BRANCO LEBRE
# 384595  DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 384600  UNIDADE ASSISTENCIAL A SAUDE INDIGENA DE TARAU...
# 384602  DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 384603  UNIDADE DE SAUDE DA FAMILIA MARIA SOLEDADE SOA...
#
#         estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 2                                 120040                     RIO BRANCO
# 8                                 120040                     RIO BRANCO
# 11                                120010                      BRASILEIA
# 12                                120020                CRUZEIRO DO SUL
# 20                                120060                       TARAUACA
# ...                                  ...                            ...
# 384594                            120033                    MANCIO LIMA
# 384595                            120040                     RIO BRANCO
# 384600                            120060                       TARAUACA
# 384602                            120040                     RIO BRANCO
# 384603                            120080                     PORTO ACRE
#
#        estabelecimento_uf vacina_categoria_nome
# 2                      AC                   NaN
# 8                      AC          Faixa Etária
# 11                     AC          Faixa Etária
# 12                     AC          Faixa Etária
# 20                     AC          Faixa Etária
# ...                   ...                   ...
# 384594                 AC                Outros
# 384595                 AC          Faixa Etária
# 384600                 AC       Povos Indígenas
# 384602                 AC          Faixa Etária
# 384603                 AC                   NaN
#
# [75698 rows x 7 columns]

# %%
df_unique_establishments = df_establishments.drop_duplicates(subset=establishment_columns)
df_unique_establishments
# Out:
#         estabelecimento_valor                 estabelecimento_razaoSocial  \
# 2                     6917291          PREFEITURA MUNICIPAL DE RIO BRANCO
# 11                    2001349           PREFEITURA MUNICIPAL DE BRASILEIA
# 12                    6159087     PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 20                    3810771            PREFEITURA MUNICIPAL DE TARAUACA
# 23                    2000660    PREFEITURA MUNICIPAL DE SENADOR GUIOMARD
# ...                       ...                                         ...
# 128240                 197599          CENTRAL MUNICIPAL DE REDE DE FRIOS
# 133958                9315578                   MUNICIPIO DE PORTO WALTER
# 151264                2001357  SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
# 205572                5493455   PREFEITURA MUNICIPAL DE PLACIDO DE CASTRO
# 224864                 755605                          USF BARRO VERMELHO
#
#                                  estalecimento_noFantasia  \
# 2       DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 11                                 ESF TUFIC MIZAEL SAADY
# 12       SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL
# 20      UNIDADE DE S DA FAMILIA DR JOSE LEONCIO GOMES ...
# 23            CENTRO DE SAUDE MARIA DO SOCORRO CAVALCANTE
# ...                                                   ...
# 128240                 CENTRAL MUNICIPAL DE REDE DE FRIOS
# 133958                   UBS FRANCISCA DAS CHAGAS LUSTOSA
# 151264                        ESF PEDRO OLIVEIRA DE SOUZA
# 205572                         U S F MARIO GOMES DA SILVA
# 224864                                 USF BARRO VERMELHO
#
#         estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 2                                 120040                     RIO BRANCO
# 11                                120010                      BRASILEIA
# 12                                120020                CRUZEIRO DO SUL
# 20                                120060                       TARAUACA
# 23                                120045               SENADOR GUIOMARD
# ...                                  ...                            ...
# 128240                            120020                CRUZEIRO DO SUL
# 133958                            120039                   PORTO WALTER
# 151264                            120010                      BRASILEIA
# 205572                            120038              PLACIDO DE CASTRO
# 224864                            120040                     RIO BRANCO
#
#        estabelecimento_uf vacina_categoria_nome
# 2                      AC                   NaN
# 11                     AC          Faixa Etária
# 12                     AC          Faixa Etária
# 20                     AC          Faixa Etária
# 23                     AC          Faixa Etária
# ...                   ...                   ...
# 128240                 AC          Faixa Etária
# 133958                 AC          Faixa Etária
# 151264                 AC          Faixa Etária
# 205572                 AC          Faixa Etária
# 224864                 AC          Faixa Etária
#
# [193 rows x 7 columns]

# %%
vaccine_counts_per_establishment = df_under_18.groupby(establishment_columns).size().reset_index(name='quantidade_vacinas_menores_18')
vaccine_counts_per_establishment
# Out:
#      estabelecimento_valor                        estabelecimento_razaoSocial  \
# 0                   115606                                K M OLIVEIRA EIRELI
# 1                   117382                                USF LIDIA RODRIGUES
# 2                   197599                 CENTRAL MUNICIPAL DE REDE DE FRIOS
# 3                   468363                                      REDE DE FRIOS
# 4                   499919                   MUNICIPIO DE SANTA ROSA DO PURUS
# ..                     ...                                                ...
# 188                9648968  DISTRITO SANITARIO ESPECIAL DE SAUDE INDIGENA ...
# 189                9830464                             MUNICIPIO DE BRASILEIA
# 190                9908382                                USF AEROPORTO VELHO
# 191                9948759                            PREFEITURA DE BRASILEIA
# 192                9957650                      SECRETARIA DE ESTADO DE SAUDE
#
#                          estalecimento_noFantasia  \
# 0                          MAIS SAUDE DIAGNOSTICO
# 1                             USF LIDIA RODRIGUES
# 2              CENTRAL MUNICIPAL DE REDE DE FRIOS
# 3                                   REDE DE FRIOS
# 4          UNIDADE BASICA DE SAUDE MANDUCA KULINA
# ..                                            ...
# 188                 UNIDADE BASICA DE SAUDE BUACU
# 189                   ESF ANTONIO CORREIA DA CRUZ
# 190                           USF AEROPORTO VELHO
# 191  ESF RAIMUNDA ANTONIA DE ARAUJO CARNEIRO LIMA
# 192                          CRIE CRUZEIRO DO SUL
#
#      estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 0                              120020                CRUZEIRO DO SUL
# 1                              120040                     RIO BRANCO
# 2                              120020                CRUZEIRO DO SUL
# 3                              120033                    MANCIO LIMA
# 4                              120043            SANTA ROSA DO PURUS
# ..                                ...                            ...
# 188                            120034                  MANOEL URBANO
# 189                            120010                      BRASILEIA
# 190                            120040                     RIO BRANCO
# 191                            120010                      BRASILEIA
# 192                            120020                CRUZEIRO DO SUL
#
#     estabelecimento_uf  quantidade_vacinas_menores_18
# 0                   AC                              1
# 1                   AC                             26
# 2                   AC                              1
# 3                   AC                            907
# 4                   AC                             17
# ..                 ...                            ...
# 188                 AC                             97
# 189                 AC                             11
# 190                 AC                             74
# 191                 AC                             48
# 192                 AC                              9
#
# [193 rows x 7 columns]

# %%
df_result = pd.merge(df_unique_establishments, vaccine_counts_per_establishment, on=establishment_columns)
df_result
# Out:
#      estabelecimento_valor                 estabelecimento_razaoSocial  \
# 0                  6917291          PREFEITURA MUNICIPAL DE RIO BRANCO
# 1                  2001349           PREFEITURA MUNICIPAL DE BRASILEIA
# 2                  6159087     PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 3                  3810771            PREFEITURA MUNICIPAL DE TARAUACA
# 4                  2000660    PREFEITURA MUNICIPAL DE SENADOR GUIOMARD
# ..                     ...                                         ...
# 188                 197599          CENTRAL MUNICIPAL DE REDE DE FRIOS
# 189                9315578                   MUNICIPIO DE PORTO WALTER
# 190                2001357  SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
# 191                5493455   PREFEITURA MUNICIPAL DE PLACIDO DE CASTRO
# 192                 755605                          USF BARRO VERMELHO
#
#                               estalecimento_noFantasia  \
# 0    DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 1                               ESF TUFIC MIZAEL SAADY
# 2     SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL
# 3    UNIDADE DE S DA FAMILIA DR JOSE LEONCIO GOMES ...
# 4          CENTRO DE SAUDE MARIA DO SOCORRO CAVALCANTE
# ..                                                 ...
# 188                 CENTRAL MUNICIPAL DE REDE DE FRIOS
# 189                   UBS FRANCISCA DAS CHAGAS LUSTOSA
# 190                        ESF PEDRO OLIVEIRA DE SOUZA
# 191                         U S F MARIO GOMES DA SILVA
# 192                                 USF BARRO VERMELHO
#
#      estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 0                              120040                     RIO BRANCO
# 1                              120010                      BRASILEIA
# 2                              120020                CRUZEIRO DO SUL
# 3                              120060                       TARAUACA
# 4                              120045               SENADOR GUIOMARD
# ..                                ...                            ...
# 188                            120020                CRUZEIRO DO SUL
# 189                            120039                   PORTO WALTER
# 190                            120010                      BRASILEIA
# 191                            120038              PLACIDO DE CASTRO
# 192                            120040                     RIO BRANCO
#
#     estabelecimento_uf vacina_categoria_nome  quantidade_vacinas_menores_18
# 0                   AC                   NaN                          25591
# 1                   AC          Faixa Etária                           1165
# 2                   AC          Faixa Etária                           1819
# 3                   AC          Faixa Etária                           3213
# 4                   AC          Faixa Etária                           2177
# ..                 ...                   ...                            ...
# 188                 AC          Faixa Etária                              1
# 189                 AC          Faixa Etária                              4
# 190                 AC          Faixa Etária                              4
# 191                 AC          Faixa Etária                              3
# 192                 AC          Faixa Etária                              1
#
# [193 rows x 8 columns]
